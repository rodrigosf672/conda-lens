# %% [markdown]
# # Interactive Demonstrations
# Use IPython magics to run diagnostics in-kernel.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path('src').resolve()))
from IPython import get_ipython
ip = get_ipython()
ip and ip.run_line_magic('load_ext', 'conda_lens.magic')

# %%
ip and ip.run_line_magic('diagnose', '')
