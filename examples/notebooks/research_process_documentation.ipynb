# %% [markdown]
# # Research Process Documentation
# Capture environment metadata and a reproducibility card for experiments.

# %%
from pathlib import Path
import sys, json
sys.path.append(str(Path('src').resolve()))
from conda_lens.env_inspect import get_active_env_info
from conda_lens.repro_card import generate_repro_card
env = get_active_env_info()
card = generate_repro_card(env)
json.dumps(card, indent=2)

# %% [markdown]
# ## Next Steps
# - Save the card to a versioned file.
# - Track changes alongside experiment runs.
